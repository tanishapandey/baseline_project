# %%
import re
import pickle
import json
import xml.etree.ElementTree as ET
from nltk.corpus import stopwords, wordnet as wn
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import os
from nltk.tokenize import word_tokenize, sent_tokenize
import numpy as np
import math
from difflib import SequenceMatcher
import pandas as pd

# %%
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
year_regex = re.compile(r'((19[0-9]{2})|(20[0-9]{2}))[a-z]?')
conversion_dict = {}

# %%
stop_words = [',', '.', '(', ')', ':', '-', "+", ";", "a", "about", "al", "al.", "all", 
	"already", "also", "although", "am", "an", "and", "another", "any", "anyhow", "are", 
	"aren", "aren't", "around", "as", "at", "back", "be", "because", "been", 
	"being", "beyond", "but", "by", "can", "cannot", "cant", "co", "con", "could", "couldn", 
	"couldnt", "d", "de", "did", "didn", "didn't", "do", "does", "doesn", "doesn't", 
	"doing", "don", "don't", "done", "due", "each", "either", "else", "elsewhere", "et", 
	"etc", "even", "ever", "except", "for", "found", "from", "further", "had", "hadn", 
	"hadn't", "has", "hasn", "hasn't", "hasnt", "have", "haven", "haven't", "having", 
	"he", "hence", "her", "here", "hereafter", "hereby", "hers", 
	"herself", "him", "himself", "his", "how", "however", "i", "ie", "if", "in", "inc", 
	"indeed", "interest", "into", "is", "isn", "isn't", "it", "it's", "its", "itself", 
	"just", "ltd", "ll", "m", "may", "me", "meanwhile", "might", "mightn", 
	"mightn't", "mine", "moreover", "most", "mostly", "move", "much", "must", "mustn", 
	"mustn't", "my", "myself", "name", "namely", "need", "needn", "needn't", "neither", 
	"nevertheless", "no", "nobody", "noone", "nor", "not", "now", "nowhere", "o", "of", 
	"off", "often", "on", "only", "onto", "or", "other", "others", "otherwise", "our", "own", 
	"per", "perhaps", "put", "rather", "re", "s", "same", "see", "seem", "seemed", 
	"seeming", "seems", "serious", "she", "should", "shouldn", "shouldn't", "since", 
	"sincere", "so", "some", "somehow", "someone", "something", "somewhere", "still", 
	"such", "t", "take", "than", "that", "that'll", "the", "their", "theirs", 
	"them", "themselves", "then", "thence", "there", "thereafter", "thereby", "therefore", 
	"therein", "thereupon", "these", "they", "this", "those", "though", "throughout", 
	"thru", "thus", "to", "together", "too", "toward", "towards", "un", "until", "upon", 
	"us", "ve", "very", "via", "was", "wasn", "wasn't", "we", "well", "were", "weren", 
	"weren't", "what", "whatever", "when", "whence", "whenever", "where", "whereafter", 
	"whereas", "whereby", "wherein", "whereupon", "wherever", "whether", "which", "while", 
	"whither", "who", "whoever", "whole", "whom", "whose", "why", "will", "with", "within", 
	"without", "won", "won't", "would", "wouldn", "wouldn't", "y", "yet", "you", "your", 
	"yours", "yourself", "yourselves", "from SVM import SVCone", "two", "three", "four", "five", "six", "seven",
	"eight", "nine", "zero", "between", 'below', 'ourselves', "you'll", 'again', 'once', 'over', 'shan', 'few', 
    'against', 'before', 'out', 'down', 'both', 'up', "you've", "shan't", "you're", "should've", 'ours', 'ma', 
    "couldn't", 'during', 'more', 'ain', 'through', 'after', 'above', "she's", "you'd", 'under' ]

# %%
def match_titles(title1, title2):
    title1 = re.sub(r'[\W_]+', '', title1).lower()
    title2 = re.sub(r'[\W_]+', '', title2).lower()
    if title1 in title2 or title2 in title1:
        return True
    return False

# %%
def find_common_words(paper_title, cit_title):

	paper_title_words = word_tokenize(paper_title.replace('-', ' ').lower())
	cit_title_words = word_tokenize(cit_title.replace('-', ' ').lower())

	final_paper_title_words = []
	for word in paper_title_words:
		if word in stop_words:
			continue
		elif re.fullmatch(r'[a-z]+', word):
			word = lemmatizer.lemmatize(word)
			final_word = stemmer.stem(word)
			word = final_word

			final_paper_title_words.append(word)

	final_cit_title_words = []
	for word in cit_title_words:
		if word in stop_words:
			continue
		elif re.fullmatch(r'[a-z]+', word):
			word = lemmatizer.lemmatize(word)
			final_word = stemmer.stem(word)
			word = final_word

			final_cit_title_words.append(word)

	return len(set(final_cit_title_words)&set(final_paper_title_words))/(len(set(final_paper_title_words)|set(final_cit_title_words)))

# %%
def get_citations(folder):
    citation_list = {}
    for file in os.listdir(folder) :
        tree = ET.parse(folder+file)
        root = tree.getroot()
        id = file[:8]
        for element in root.iterfind("algorithm"):
            if(element.attrib['name']=="ParsCit"):
                citlist = element.getchildren()
                cits = citlist[0].getchildren()
                citations = []
                for cit in cits:
                    cit_dict = {}
                    if(cit.attrib['valid']=="true"):
                        try :
                            title = cit.find('title').text.lower()
                        except :
                            title = cit.find('rawString').text.lower()
                        cit_dict['title'] = title
                        cit_dict['cit'] = cit
                        citations.append(cit_dict)
                
                citation_list[id] = citations
            
    return citation_list

# %%
def get_popularity_feat(citations) :
    global_citStr = []
    for key in citations :
        papers = citations[key]
        for paper in papers :
            global_citStr.extend(list(set([context.get('citStr').lower() for context in paper['cit'].findall('contexts/context')])))
    global_citStr = list(set(global_citStr))
    
    dataset = {}
    count=0
    for key in citations :
        papers = citations[key]
        data = []
        for paper in papers :
            dict1 = {}
            dict1['paper_name'] = paper['title']
            citStrs = list(set([context.get('citStr').lower() for context in paper['cit'].findall('contexts/context')]))
            other_cits = list(set(global_citStr)-set(citStrs))
            count_pop = 0
            for context in paper['cit'].findall('contexts/context') :
                con_text = context.text.lower()
                sentences = sent_tokenize(con_text)
                for sent in sentences :
                    for citstr in citStrs :
                        if(citstr in sent) :
                            for cit in other_cits :
                                count_pop+= con_text.count(cit)                
            dict1['popularity'] = count_pop
            data.append(dict1)
        if(count%100==0) :
            print(count)
        count+=1
        dataset[key] = data
        
    return global_citStr, dataset

# %%
def get_paper_titles(folder) :
    names = {}
    papers = []
    count = 0
    for file in os.listdir(folder) :
        tree = ET.parse(folder+file)
        root = tree.getroot()
        id = file[:8]
        for element in root.iterfind("algorithm"):
            if(element.attrib['name']=="SectLabel"):
                for elem in element.iterfind('variant/'):
                    if(elem.tag == "title"):
                        names[id] = elem.text
        papers.append(id)
                        
    ids_not_found = list(set(papers)-set(names.keys()))
    for id in ids_not_found :
        try :
            tree = ET.parse("titles/"+id[0]+"/"+id[:3]+"/"+id[:3]+".xml")
            root = tree.getroot()
            for element in root.iterfind("paper"):
                if(element.attrib['id']==id[4:]):
                    names[id] = element.find('title').text.lower()
        except :
            names[id] = ''
            count+=1
    
    print(count)
    return names

# %%
paper_titles = get_paper_titles("xmls/")
# Out:
# 1

# %%
pickle.dump(paper_titles, open("pickles_data/acl_paper_titles.pkl", "wb"))

# %%
paper_tits = {}
authors_acl = pickle.load(open("pickles_data/authors_acl.pkl","rb"))
count = 0
for key in paper_titles :
    data = {}
    data['paper_name'] = paper_titles[key].lower().replace("\n", " ")
    year = int(key[1:3])
    year_str = ""
    if(year>=0 and year<=20) :
        if(len(str(year))==1):
            year_str = "200"+str(year)
        else :
            year_str = "20"+str(year)
    else :
        year_str = "19" + str(year)
    data['year'] = year_str    
    data['authors'] = authors_acl[key]
    if(len(data['authors'])==0) :
        count+=1
    paper_tits[key] = data 
print(count)
# Out:
# 148

# %%
paper_tits
# Out:
# {'P10-1026': {'paper_name': ' a bayesian method for robust estimation of distributional similarities ',
#   'year': '2010',
#   'authors': ['jun’ichi kazama',
#    'stijn de saeger',
#    'kow kuroda',
#    'masaki murata',
#    'kentaro torisawa']},
#  'P13-1111': {'paper_name': ' handling ambiguities of bilingual predicate-argument structures for statistical machine translation ',
#   'year': '2013',
#   'authors': ['feifei zhai', 'jiajun zhang', 'yu zhou', 'chengqing zong']},
#  'W14-4407': {'paper_name': ' a template-based abstractive meeting summarization: leveraging summary and source text relationships ',
#   'year': '2014',
#   'authors': []},
#  'D10-1003': {'paper_name': ' utilizing extra-sentential context for parsing ',
#   'year': '2010',
#   'authors': []},
#  'P13-1171': {'paper_name': ' question answering using enhanced lexical semantic models ',
#   'year': '2013',
#   'authors': ['wen-tau yih',
#    'ming-wei chang',
#    'christopher meek',
#    'andrzej pastusiak']},
#  'J15-1005': {'paper_name': ' automatic adaptation of annotations ',
#   'year': '2015',
#   'authors': ['wenbin jiang', 'yajuan lü', 'liang huang', 'qun liu']},
#  'N09-1036': {'paper_name': ' improving nonparameteric bayesian inference: experiments on unsupervised word segmentation with adaptor grammars ',
#   'year': '2009',
#   'authors': ['mark johnson', 'sharon goldwater']},
#  'P11-1130': {'paper_name': ' translating from morphologically complex languages: a paraphrase-based approach ',
#   'year': '2011',
#   'authors': ['preslav nakov', 'hwee tou ng']},
#  'P13-1029': {'paper_name': ' transfer learning for constituency-based grammars ',
#   'year': '2013',
#   'authors': ['yuan zhang', 'regina barzilay', 'amir globerson']},
#  'D15-1136': {'paper_name': ' parsing english into abstract meaning representation using syntax-based machine translation ',
#   'year': '2015',
#   'authors': ['michael pust',
#    'ulf hermjakob',
#    'kevin knight',
#    'daniel marcu',
#    'jonathan may']},
#  'P13-1087': {'paper_name': ' density maximization in context-sense metric space for all-words wsd ',
#   'year': '2013',
#   'authors': ['koichi tanigaki',
#    'mitsuteru shiba',
#    'tatsuji munaka',
#    'yoshinori sagisaka']},
#  'N06-1047': {'paper_name': ' incorporating speaker and discourse features into speech summarization ',
#   'year': '2006',
#   'authors': []},
#  'Q14-1008': {'paper_name': ' exploring the role of stress in bayesian word segmentation using adaptor grammars ',
#   'year': '2014',
#   'authors': []},
#  'P91-1041': {'paper_name': ' quasi-destructive graph unification ',
#   'year': '1991',
#   'authors': ['hideto tomabechi']},
#  'W10-2915': {'paper_name': ' learning probabilistic synchronous cfgs for phrase-based translation ',
#   'year': '2010',
#   'authors': ['markos mylonakis', 'khalil sima’an']},
#  'D15-1218': {'paper_name': ' a coarse-grained model for optimal coupling of asr and smt systems for speech translation ',
#   'year': '2015',
#   'authors': ['gaurav kumar',
#    'graeme blackwood',
#    'jan trmal',
#    'daniel povey',
#    'sanjeev khudanpur']},
#  'P15-1135': {'paper_name': ' probing the linguistic strengths and limitations of unsupervised grammar induction ',
#   'year': '2015',
#   'authors': ['yonatan bisk', 'julia hockenmaier']},
#  'P00-1039': {'paper_name': ' an algorithm for one-page summarization of a long text based on thematic hierarchy detection ',
#   'year': '2000',
#   'authors': ['yoshio nakao']},
#  'P13-1118': {'paper_name': ' derivbase: inducing and evaluating a derivational morphology resource for german ',
#   'year': '2013',
#   'authors': ['britta zeller', 'jan šnajder', 'sebastian padó']},
#  'D12-1002': {'paper_name': ' regularized interlingual projections: evaluation on multilingual transliteration ',
#   'year': '2012',
#   'authors': ['jagadeesh jagarlamudi', 'hal daume iii']},
#  'W15-4902': {'paper_name': ' building hybrid machine translation systems by using an ebmt preprocessor to create partial translations ',
#   'year': '2015',
#   'authors': ['mikel artetxe', 'gorka labaka', 'kepa sarasola']},
#  'S15-1005': {'paper_name': ' combining seemingly incompatible corpora for implicit semantic role labeling ',
#   'year': '2015',
#   'authors': []},
#  'W06-2914': {'paper_name': ' word distributions for thematic segmentation in a support vector machine approach ',
#   'year': '2006',
#   'authors': ['maria georgescul', 'alexander clark', 'susan armstrong']},
#  'P15-1127': {'paper_name': ' scalable semantic parsing with partial ontologies ',
#   'year': '2015',
#   'authors': ['eunsol choi', 'tom kwiatkowski', 'luke zettlemoyer']},
#  'P13-1109': {'paper_name': ' graph propagation for paraphrasing out-of-vocabulary words in statistical machine translation∗ ',
#   'year': '2013',
#   'authors': ['majid razmara',
#    'maryam siahbani',
#    'reza haffari',
#    'anoop sarkar']},
#  'D12-1120': {'paper_name': ' biased representation learning for domain adaptation ',
#   'year': '2012',
#   'authors': ['fei huang', 'alexander yates']},
#  'W13-3514': {'paper_name': ' frame semantics for stance classification ',
#   'year': '2013',
#   'authors': ['kazi saidul hasan', 'vincent ng']},
#  'P14-1095': {'paper_name': ' language-aware truth assessment of fact candidates ',
#   'year': '2014',
#   'authors': []},
#  'D12-1019': {'paper_name': ' spectral dependency parsing with latent variables ',
#   'year': '2012',
#   'authors': ['paramveer dhillon',
#    'jordan rodu',
#    'michael collins',
#    'dean foster',
#    'lyle ungar']},
#  'N13-1132': {'paper_name': ' learning whom to trust with mace ',
#   'year': '2013',
#   'authors': ['dirk hovy',
#    'taylor berg-kirkpatrick',
#    'ashish vaswani',
#    'eduard hovy']},
#  'P02-1059': {'paper_name': ' supervised ranking in open-domain text summarization ',
#   'year': '2002',
#   'authors': ['tadashi nomoto', 'yuji matsumoto']},
#  'J12-1003': {'paper_name': ' learning entailment relations by global graph structure optimization ',
#   'year': '2012',
#   'authors': ['jonathan berant', 'ido dagan', 'jacob goldberger']},
#  'D12-1134': {'paper_name': ' identifying event-related bursts via social media activities ',
#   'year': '2012',
#   'authors': ['xin zhao',
#    'baihan shu',
#    'jing jiang',
#    'yang song',
#    'hongfei yan',
#    'xiaoming li']},
#  'W14-4338': {'paper_name': ' optimizing generative dialog state tracker via cascading gradient descent ',
#   'year': '2014',
#   'authors': []},
#  'Q13-1009': {'paper_name': ' using pivot-based paraphrasing and sentiment profiles to improve a subjectivity lexicon for essay data ',
#   'year': '2013',
#   'authors': []},
#  'P13-1059': {'paper_name': ' name-aware machine translation ',
#   'year': '2013',
#   'authors': ['haibo li', 'jing zheng', 'heng ji', 'qi li', 'wen wang']},
#  'P06-1009': {'paper_name': ' discriminative word alignment with conditional random fields ',
#   'year': '2006',
#   'authors': ['phil blunsom', 'trevor cohn']},
#  'N10-1014': {'paper_name': ' unsupervised syntactic alignment with inversion transduction grammars ',
#   'year': '2010',
#   'authors': ['adam pauls', 'dan klein', 'david chiang', 'kevin knight']},
#  'P10-1107': {'paper_name': ' a statistical model for lost language decipherment ',
#   'year': '2010',
#   'authors': ['benjamin snyder', 'regina barzilay', 'kevin knight']},
#  'N01-1011': {'paper_name': ' a decision tree of bigrams is an accurate predictor of word sense ',
#   'year': '2001',
#   'authors': []},
#  'P02-1065': {'paper_name': ' memory-based learning of morphology with stochastic transducers ',
#   'year': '2002',
#   'authors': ['alexander clark']},
#  'P14-1136': {'paper_name': ' semantic frame identification with distributed word representations ',
#   'year': '2014',
#   'authors': []},
#  'P08-1048': {'paper_name': ' evaluating roget’s thesauri ',
#   'year': '2008',
#   'authors': ['alistair kennedy', 'stan szpakowicz']},
#  'D08-1034': {'paper_name': ' improving chinese semantic role classification with hierarchical feature selection strategy ',
#   'year': '2008',
#   'authors': ['weiwei ding', 'baobao chang']},
#  'D08-1090': {'paper_name': ' language and translation model adaptation using comparable corpora ',
#   'year': '2008',
#   'authors': ['matthew snover', 'bonnie dorr', 'richard schwartz']},
#  'D09-1092': {'paper_name': ' polylingual topic models ',
#   'year': '2009',
#   'authors': ['david mimno',
#    'hanna m. wallach',
#    'jason naradowsky',
#    'david a. smith',
#    'andrew mccallum']},
#  'P10-1125': {'paper_name': ' modeling semantic relevance for question-answer pairs in web social communities ',
#   'year': '2010',
#   'authors': ['baoxun wang',
#    'xiaolong wang',
#    'chengjie sun',
#    'bingquan liu',
#    'lin sun']},
#  'D15-1089': {'paper_name': ' convolutional sentence kernel from word embeddings for short text categorization ',
#   'year': '2015',
#   'authors': ['jonghoon kim', 'francois rousseau', 'michalis vazirgiannis']},
#  'D12-1051': {'paper_name': ' exploiting chunk-level features to improve phrase chunking ',
#   'year': '2012',
#   'authors': ['junsheng zhou', 'weiguang qu', 'fen zhang']},
#  'E12-1008': {'paper_name': ' dependency parsing with undirected graphs ',
#   'year': '2012',
#   'authors': ['carlos gómez-rodríguez', 'daniel fernández-gonzález']},
#  'E14-1075': {'paper_name': ' improving the estimation of word importance for news multi-document summarization ',
#   'year': '2014',
#   'authors': ['kai hong', 'ani nenkova']},
#  'D14-1123': {'paper_name': ' exploiting community emotion for microblog event detection ',
#   'year': '2014',
#   'authors': ['gaoyan ou',
#    'wei chen',
#    'tengjiao wang',
#    'zhongyu wei',
#    'binyang li',
#    'dongqing yang',
#    'kam-fai wong']},
#  'D09-1036': {'paper_name': ' recognizing implicit discourse relations in the penn discourse treebank ',
#   'year': '2009',
#   'authors': ['ziheng lin', 'min-yen kan', 'hwee tou ng']},
#  'S15-1017': {'paper_name': ' dissecting the practical lexical function model for compositional distributional semantics ',
#   'year': '2015',
#   'authors': []},
#  'P12-1072': {'paper_name': ' a probabilistic model for canonicalizing named entity mentions ',
#   'year': '2012',
#   'authors': ['dani yogatama', 'yanchuan sim', 'noah a. smith']},
#  'P12-1007': {'paper_name': ' text-level discourse parsing with rich linguistic features ',
#   'year': '2012',
#   'authors': ['vanessa wei feng', 'graeme hirst']},
#  'P03-1011': {'paper_name': ' loosely tree-based alignment for machine translation ',
#   'year': '2003',
#   'authors': ['daniel gildea']},
#  'P14-1012': {'paper_name': ' learning new semi-supervised deep auto-encoder features for statistical machine translation ',
#   'year': '2014',
#   'authors': []},
#  'W06-1649': {'paper_name': ' partially supervised sense disambiguation by learning sense number from tagged and untagged corpora ',
#   'year': '2006',
#   'authors': ['zheng-yu niu', 'dong-hong ji', 'chew lim tan']},
#  'W15-5618': {'paper_name': ' on strategies of human multi-document summarization ',
#   'year': '2015',
#   'authors': ['renata tironi de camargo',
#    'ariani di felippo',
#    'thiago a. s. pardo']},
#  'N07-1011': {'paper_name': ' first-order probabilistic models for coreference resolution ',
#   'year': '2007',
#   'authors': ['aron culotta', 'michael wick', 'andrew mccallum']},
#  'D08-1069': {'paper_name': ' specialized models and ranking for coreference resolution ',
#   'year': '2008',
#   'authors': ['pascal denis', 'jason baldridge']},
#  'D08-1113': {'paper_name': ' latent-variable modeling of string transductions with finite-state methods* ',
#   'year': '2008',
#   'authors': ['markus dreyer', 'jason smith', 'jason eisner']},
#  'D14-1008': {'paper_name': ' a constituent-based approach to argument labeling with joint inference in discourse parsing ',
#   'year': '2014',
#   'authors': ['fang kong', 'hwee tou ng', 'guodong zhou']},
#  'P98-2234': {'paper_name': ' some properties of preposition and subordinate conjunction attachments* ',
#   'year': '1998',
#   'authors': ['alexander s. yeh and marc b. vilain']},
#  'P11-1149': {'paper_name': ' confidence driven unsupervised semantic parsing ',
#   'year': '2011',
#   'authors': ['dan goldwasser', 'roi reichart', 'james clarke', 'dan roth']},
#  'P08-1049': {'paper_name': ' unsupervised translation induction for chinese abbreviations using monolingual corpora ',
#   'year': '2008',
#   'authors': ['zhifei li', 'david yarowsky']},
#  'P14-1015': {'paper_name': ' unsupervised solution post identification from discussion forums ',
#   'year': '2014',
#   'authors': []},
#  'D13-1191': {'paper_name': ' learning topics and positions from debatepedia ',
#   'year': '2013',
#   'authors': ['swapna gottipati',
#    'minghui qiu',
#    'yanchuan sim',
#    'jing jiang',
#    'noah a. smith']},
#  'D14-1038': {'paper_name': ' renoun: fact extraction for nominal attributes ',
#   'year': '2014',
#   'authors': ['mohamed yahya', 'steven whang', 'rahul gupta', 'alon halevy']},
#  'P10-1004': {'paper_name': ' computing weakest readings ',
#   'year': '2010',
#   'authors': ['alexander koller', 'stefan thater']},
#  'P14-1033': {'paper_name': ' aspect extraction with automated prior knowledge learning ',
#   'year': '2014',
#   'authors': []},
#  'D13-1014': {'paper_name': ' modeling and learning semantic co-compositionality through prototype projections and neural networks ',
#   'year': '2013',
#   'authors': ['masashi tsubaki',
#    'kevin duh',
#    'masashi shimbo',
#    'yuji matsumoto']},
#  'D11-1030': {'paper_name': ' universal morphological analysis using structured nearest neighbor prediction ',
#   'year': '2011',
#   'authors': ['young-bum kim', 'joão graça', 'benjamin snyder']},
#  'P05-1004': {'paper_name': ' supersense tagging of unknown nouns using semantic similarity ',
#   'year': '2005',
#   'authors': ['james curran']},
#  'D15-1045': {'paper_name': ' scientific article summarization using citation-context and article’s discourse structure ',
#   'year': '2015',
#   'authors': ['arman cohan', 'nazli goharian']},
#  'P13-1013': {'paper_name': ' chinese parsing exploiting characters ',
#   'year': '2013',
#   'authors': ['meishan zhang', 'yue zhang', 'wanxiang che', 'ting liu']},
#  'P01-1041': {'paper_name': ' japanese named entity recognition based on a simple rule generator and decision tree learning ',
#   'year': '2001',
#   'authors': []},
#  'J01-1002': {'paper_name': ' integrating prosodic and lexical cues for automatic topic segmentation ',
#   'year': '2001',
#   'authors': ['gokhan tur',
#    'andreas stolcke',
#    'dilek hakkani-tur',
#    'elizabeth shriberg']},
#  'P00-1011': {'paper_name': ' tagging unknown proper names using decision trees ',
#   'year': '2000',
#   'authors': ['frédéric béchet', 'alexis nasr', 'franck genet']},
#  'D13-1009': {'paper_name': ' question difficulty estimation in community question answering services∗ ',
#   'year': '2013',
#   'authors': ['jing liu', 'quan wang', 'chin-yew lin', 'hsiao-wuen hon']},
#  'P05-1015': {'paper_name': ' seeing stars: exploiting class relationships for sentiment categorization with respect to rating scales ',
#   'year': '2005',
#   'authors': ['bo pang', 'lillian lee']},
#  'D14-1137': {'paper_name': ' semantic parsing with relaxed hybrid trees ',
#   'year': '2014',
#   'authors': ['wei lu']},
#  'D15-1040': {'paper_name': ' a neural network model for low-resource universal dependency parsing ',
#   'year': '2015',
#   'authors': ['long duong', 'trevor cohn', 'steven bird', 'paul cook']},
#  'E12-1060': {'paper_name': ' word sense induction for novel sense detection ',
#   'year': '2012',
#   'authors': ['jey han lau',
#    'paul cook',
#    'diana mccarthy',
#    'david newman',
#    'timothy baldwin']},
#  'N09-1029': {'paper_name': ' learning bilingual linguistic reordering model for statistical machine translation ',
#   'year': '2009',
#   'authors': ['han-bin chen', 'jian-cheng wu', 'jason s. chang']},
#  'P15-1001': {'paper_name': ' on using very large target vocabulary for neural machine translation ',
#   'year': '2015',
#   'authors': ['sébastien jean',
#    'kyunghyun cho',
#    'roland memisevic',
#    'yoshua bengio']},
#  'P14-1115': {'paper_name': ' abstractive summarization of spoken and written conversations based on phrasal queries ',
#   'year': '2014',
#   'authors': []},
#  'P13-1107': {'paper_name': ' resolving entity morphs in censored data ',
#   'year': '2013',
#   'authors': ['hongzhao huang',
#    'zhen wen',
#    'dian yu',
#    'heng ji',
#    'yizhou sun',
#    'jiawei han',
#    'he li']},
#  'D14-1204': {'paper_name': ' automatic inference of the tense of chinese events using implicit linguistic information ',
#   'year': '2014',
#   'authors': ['yuchen zhang', 'nianwen xue']},
#  'P09-1049': {'paper_name': ' bilingual co-training for monolingual hyponymy-relation acquisition ',
#   'year': '2009',
#   'authors': ['jong-hoon oh', 'kiyotaka uchimoto', 'kentaro torisawa']},
#  'D14-1189': {'paper_name': ' detecting non-compositional mwe components using wiktionary ',
#   'year': '2014',
#   'authors': ['bahar salehi', 'paul cook', 'timothy baldwin']},
#  'W14-4325': {'paper_name': ' initiative taking in negotiation ',
#   'year': '2014',
#   'authors': []},
#  'D13-1067': {'paper_name': ' collective personal profile summarization with social networks ',
#   'year': '2013',
#   'authors': ['zhongqing wang', 'shoushan li', 'fang kong', 'guodong zhou']},
#  'D14-1171': {'paper_name': ' fast and accurate misspelling correction in large corpora ',
#   'year': '2014',
#   'authors': ['octavian popescu', 'ngoc phuoc an vo']},
#  'D14-1045': {'paper_name': ' composition of word representations improves semantic role labelling ',
#   'year': '2014',
#   'authors': ['michael roth', 'kristian woodsend']},
#  'D12-1029': {'paper_name': ' improving transition-based dependency parsing with buffer transitions ',
#   'year': '2012',
#   'authors': ['daniel fernández-gonzález', 'carlos gómez-rodrìguez']},
#  'P14-1044': {'paper_name': ' a robust approach to aligning heterogeneous lexical resources ',
#   'year': '2014',
#   'authors': []},
#  'D13-1047': {'paper_name': ' document summarization via guided sentence compression ',
#   'year': '2013',
#   'authors': ['chen li', 'fei liu', 'fuliang weng', 'yang liu']},
#  'D13-1103': {'paper_name': ' the answer is at your fingertips: improving passage retrieval for web question answering with search behavior data ',
#   'year': '2013',
#   'authors': ['mikhail ageev', 'dmitry lagun', 'eugene agichtein']},
#  'E12-1034': {'paper_name': ' skip n-grams and ranking functions for predicting script events ',
#   'year': '2012',
#   'authors': ['bram jans',
#    'steven bethard',
#    'ivan vulić',
#    'marie-francine moens']},
#  'D15-1156': {'paper_name': ' empty category detection using path features and distributed case frames ',
#   'year': '2015',
#   'authors': ['shunsuke takeno', 'masaaki nagata', 'kazuhide yamamoto']},
#  'N13-1015': {'paper_name': ' experiments with spectral learning of latent-variable pcfgs ',
#   'year': '2013',
#   'authors': ['shay b. cohen',
#    'karl stratos',
#    'michael collins',
#    'dean p. foster',
#    'lyle ungar']},
#  'J90-3003': {'paper_name': ' a computational grammar of discourse-neutral prosodic phrasing in english ',
#   'year': '1990',
#   'authors': ['j. bachenko', 'e. fitzpatrick']},
#  'D11-1083': {'paper_name': ' heuristic search for non-bottom-up tree structure prediction ',
#   'year': '2011',
#   'authors': ['andrea gesmundo', 'james henderson']},
#  'D13-1081': {'paper_name': ' what is hidden among translation rules ',
#   'year': '2013',
#   'authors': ['libin shen', 'bowen zhou']},
#  'P14-1008': {'paper_name': ' logical inference on dependency-based compositional semantics ',
#   'year': '2014',
#   'authors': []},
#  'P96-1025': {'paper_name': ' a new statistical parser based on bigram lexical dependencies ',
#   'year': '1996',
#   'authors': ['michael john collins']},
#  'N01-1006': {'paper_name': ' transformation-based learning in the fast lane ',
#   'year': '2001',
#   'authors': []},
#  'D12-1075': {'paper_name': ' type-supervised hidden markov models for part-of-speech tagging with incomplete tag dictionaries ',
#   'year': '2012',
#   'authors': ['dan garrette', 'jason baldridge']},
#  'P00-1061': {'paper_name': ' lexicalized stochastic modeling of constraint-based grammars using log-linear measures and em training ',
#   'year': '2000',
#   'authors': ['stefan riezler',
#    'detlef prescher',
#    'jonas kuhn',
#    'mark johnson']},
#  'D14-1043': {'paper_name': ' multi-resolution language grounding with weak supervision ',
#   'year': '2014',
#   'authors': ['r. koncel-kedziorski', 'hannaneh hajishirzi', 'ali farhadi']},
#  'P05-1002': {'paper_name': ' scaling conditional random fields using error-correcting codes ',
#   'year': '2005',
#   'authors': ['trevor cohn', 'andrew smith', 'miles osborne']},
#  'D14-1014': {'paper_name': ' submodularity for data selection in statistical machine translation ',
#   'year': '2014',
#   'authors': ['katrin kirchhoff', 'jeff bilmes']},
#  'N10-1134': {'paper_name': ' multi-document summarization via budgeted maximization of submodular functions ',
#   'year': '2010',
#   'authors': ['hui lin', 'jeff bilmes']},
#  'P15-1017': {'paper_name': ' event extraction via dynamic multi-pooling convolutional neural networks ',
#   'year': '2015',
#   'authors': ['yubo chen',
#    'liheng xu',
#    'kang liu',
#    'daojian zeng',
#    'jun zhao']},
#  'D11-1005': {'paper_name': ' unsupervised structure prediction with non-parallel multilingual guidance ',
#   'year': '2011',
#   'authors': ['shay b. cohen', 'dipanjan das', 'noah a. smith']},
#  'P14-1036': {'paper_name': ' collective tweet wikification based on semi-supervised graph regularization ',
#   'year': '2014',
#   'authors': []},
#  'D15-1177': {'paper_name': ' syntax-aware multi-sense word embeddings for deep compositional models of meaning ',
#   'year': '2015',
#   'authors': ['jianpeng cheng', 'dimitri kartsaklis']},
#  'P02-1054': {'paper_name': ' is it the right answer? exploiting web redundancy for answer validation ',
#   'year': '2002',
#   'authors': ['bernardo magnini',
#    'matteo negri',
#    'roberto prevete',
#    'hristo tanev']},
#  'P08-1099': {'paper_name': ' generalized expectation criteria for semi-supervised learning of conditional random fields ',
#   'year': '2008',
#   'authors': ['gideon s. mann', 'andrew mccallum']},
#  'D15-1016': {'paper_name': ' cross-lingual sentiment analysis using modified brae ',
#   'year': '2015',
#   'authors': ['sarthak jain', 'shashank batra']},
#  'D10-1102': {'paper_name': ' multi-level structured models for document-level sentiment classification ',
#   'year': '2010',
#   'authors': []},
#  'W02-1006': {'paper_name': ' an empirical evaluation of knowledge sources and learning algorithms for word sense disambiguation ',
#   'year': '2002',
#   'authors': ['yoong keok lee', 'hwee tou ng']},
#  'P09-1050': {'paper_name': ' automatic set instance extraction using the web ',
#   'year': '2009',
#   'authors': ['richard c. wang', 'william w. cohen']},
#  'P12-1011': {'paper_name': ' labeling documents with timestamps: learning from their time expressions ',
#   'year': '2012',
#   'authors': ['nathanael chambers']},
#  'J14-4004': {'paper_name': ' latent trees for coreference resolution eraldo rezende fernandes* instituto federal de goi´as ',
#   'year': '2014',
#   'authors': ['eraldo rezende fernandes',
#    'cícero nogueira dos santos',
#    'ruy luiz milidiú']},
#  'E09-1005': {'paper_name': ' personalizing pagerank for word sense disambiguation ',
#   'year': '2009',
#   'authors': ['eneko agirre', 'aitor soroa']},
#  'D15-1296': {'paper_name': ' a tableau prover for natural logic and language ',
#   'year': '2015',
#   'authors': ['lasha abzianidze']},
#  'N12-1023': {'paper_name': ' structured ramp loss minimization for machine translation ',
#   'year': '2012',
#   'authors': ['kevin gimpel', 'noah a. smith']},
#  'P06-1141': {'paper_name': ' an effective two-stage model for exploiting non-local dependencies in named entity recognition ',
#   'year': '2006',
#   'authors': ['vijay krishnan', 'christopher d. manning']},
#  'J10-3005': {'paper_name': ' discourse constraints for document compression ',
#   'year': '2010',
#   'authors': ['james clarke', 'mirella lapata']},
#  'P10-1060': {'paper_name': ' generating focused topic-specific sentiment lexicons ',
#   'year': '2010',
#   'authors': ['valentin jijkoun', 'maarten rijke', 'wouter weerkamp']},
#  'D13-1004': {'paper_name': ' exploring the utility of joint morphological and syntactic learning from child-directed speech ',
#   'year': '2013',
#   'authors': ['stella frank', 'frank keller', 'sharon goldwater']},
#  'D15-1061': {'paper_name': ' an entity-centric approach for overcoming knowledge graph sparsity ',
#   'year': '2015',
#   'authors': ['manjunath hegde', 'partha p. talukdar']},
#  'J12-4002': {'paper_name': ' finite-state chart constraints for reduced complexity context-free parsing pipelines ',
#   'year': '2012',
#   'authors': ['brian roark', 'kristy hollingshead', 'nathan bodenstab']},
#  'D11-1014': {'paper_name': ' semi-supervised recursive autoencoders for predicting sentiment distributions ',
#   'year': '2011',
#   'authors': ['richard socher',
#    'jeffrey pennington',
#    'eric h. huang',
#    'andrew y. ng',
#    'christopher d. manning']},
#  'N13-1107': {'paper_name': ' open information extraction with tree kernels ',
#   'year': '2013',
#   'authors': ['ying xu',
#    'mi-young kim',
#    'kevin quinn',
#    'randy goebel',
#    'denilson barbosa']},
#  'D14-1219': {'paper_name': ' discriminative reranking of discourse parses using tree kernels ',
#   'year': '2014',
#   'authors': ['shafiq joty', 'alessandro moschitti']},
#  'P15-1002': {'paper_name': ' addressing the rare word problem in neural machine translation ',
#   'year': '2015',
#   'authors': ['thang luong',
#    'ilya sutskever',
#    'quoc le',
#    'oriol vinyals',
#    'wojciech zaremba']},
#  'D14-1093': {'paper_name': ' domain adaptation for crf-based chinese word segmentation using free annotations ',
#   'year': '2014',
#   'authors': ['yijia liu', 'yue zhang', 'wanxiang che', 'ting liu', 'fan wu']},
#  'E09-1013': {'paper_name': ' bayesian word sense induction ',
#   'year': '2009',
#   'authors': ['samuel brody', 'mirella lapata']},
#  'P15-1089': {'paper_name': ' tweet normalization with syllables ',
#   'year': '2015',
#   'authors': ['ke xu', 'yunqing xia', 'chin-hui lee']},
#  'P96-1010': {'paper_name': ' combining trigram-based and feature-based methods for context-sensitive spelling correction ',
#   'year': '1996',
#   'authors': ['andrew golding', 'yves schabes']},
#  'D13-1131': {'paper_name': ' this text has the scent of starbucks: a laplacian structured sparsity model for computational branding analytics ',
#   'year': '2013',
#   'authors': ['william yang wang', 'edward lin', 'john kominek']},
#  'N09-1022': {'paper_name': ' japanese query alteration based on semantic similarity ',
#   'year': '2009',
#   'authors': ['masato hagiwara', 'hisami suzuki']},
#  'D15-1037': {'paper_name': ' efficient methods for incorporating knowledge into topic models ',
#   'year': '2015',
#   'authors': ['yi yang', 'doug downey', 'jordan boyd-graber']},
#  'D15-1020': {'paper_name': ' cross-document event coreference resolution based on cross-media features ',
#   'year': '2015',
#   'authors': ['tongtao zhang', 'hongzhi li', 'heng ji', 'shih-fu chang']},
#  'N03-1027': {'paper_name': ' supervised and unsupervised pcfg adaptation to novel domains ',
#   'year': '2003',
#   'authors': ['brian roark', 'michiel bacchiani']},
#  'E99-1023': {'paper_name': ' representing text chunks ',
#   'year': '1999',
#   'authors': ['erik f. tjong', 'kim sang', 'jorn veenstra']},
#  'P10-1134': {'paper_name': ' learning word-class lattices for definition and hypernym extraction ',
#   'year': '2010',
#   'authors': ['roberto navigli', 'paola velardi']},
#  'D13-1044': {'paper_name': ' automatic feature engineering for answer selection and extraction ',
#   'year': '2013',
#   'authors': ['aliaksei severyn', 'alessandro moschitti']},
#  'E14-1073': {'paper_name': ' fast recursive multi-class classification of pairs of text entities for biomedical event extraction ',
#   'year': '2014',
#   'authors': ['xiao liu', 'antoine bordes', 'yves grandvalet']},
#  'W06-1657': {'paper_name': ' short text authorship attribution via sequence kernels, markov chains and author unmasking: an investigation ',
#   'year': '2006',
#   'authors': ['conrad sanderson', 'simon guenter']},
#  'D09-1071': {'paper_name': ' the infinite hmm for unsupervised pos tagging ',
#   'year': '2009',
#   'authors': ['jurgen van gael', 'andreas vlachos', 'zoubin ghahramani']},
#  'J94-4002': {'paper_name': ' an algorithm for pronominal anaphora resolution ',
#   'year': '1994',
#   'authors': ['shalom lappin', 'herbert j. leass']},
#  'P03-1001': {'paper_name': ' offline strategies for online question answering: answering questions before they are asked ',
#   'year': '2003',
#   'authors': ['michael fleischman', 'eduard hovy', 'abdessamad echihabi']},
#  'D11-1142': {'paper_name': ' identifying relations for open information extraction ',
#   'year': '2011',
#   'authors': ['anthony fader', 'stephen soderland', 'oren etzioni']},
#  'D14-1035': {'paper_name': ' parsing low-resource languages using gibbs sampling for pcfgs with latent annotations ',
#   'year': '2014',
#   'authors': ['liang sun', 'jason mielens', 'jason baldridge']},
#  'P13-1105': {'paper_name': ' bilingually-guided monolingual dependency grammar induction ',
#   'year': '2013',
#   'authors': ['kai liu', 'yajuan lü', 'wenbin jiang', 'qun liu']},
#  'D11-1051': {'paper_name': ' semantic topic models: combining word distributional statistics and dictionary definitions ',
#   'year': '2011',
#   'authors': ['weiwei guo', 'mona diab']},
#  'D13-1164': {'paper_name': ' a convex alternative to ibm model 2 ',
#   'year': '2013',
#   'authors': ['andrei simion', 'michael collins', 'cliff stein']},
#  'W11-0131': {'paper_name': ' structured composition of semantic vectors ',
#   'year': '2011',
#   'authors': ['stephen wu', 'william schuler']},
#  'D14-1017': {'paper_name': ' unsupervised word alignment using frequency constraint in posterior regularized em ',
#   'year': '2014',
#   'authors': ['hidetaka kamigaito',
#    'taro watanabe',
#    'hiroya takamura',
#    'manabu okumura']},
#  'P13-1086': {'paper_name': ' semantic frames to predict stock price movement ',
#   'year': '2013',
#   'authors': ['boyi xie',
#    'rebecca j. passonneau',
#    'leon wu',
#    'germán g. creamer']},
#  'D08-1096': {'paper_name': ' a graph-theoretic model of lexical syntactic acquisition ',
#   'year': '2008',
#   'authors': ['hinrich schütze', 'michael walsh']},
#  'Q14-1021': {'paper_name': ' entity linking on microblogs with spatial and temporal signals ',
#   'year': '2014',
#   'authors': []},
#  'E14-1035': {'paper_name': ' dynamic topic adaptation for phrase-based mt ',
#   'year': '2014',
#   'authors': ['eva hasler', 'phil blunsom', 'philipp koehn', 'barry haddow']},
#  'N10-1076': {'paper_name': ' automatic diacritization for low-resource languages using a hybrid word and consonant cmm ',
#   'year': '2010',
#   'authors': ['robbie haertel', 'peter mcclanahan', 'eric k. ringger']},
#  'D15-1101': {'paper_name': ' c3el: a joint model for cross-document co-reference resolution and entity linking ',
#   'year': '2015',
#   'authors': ['sourav dutta', 'gerhard weikum']},
#  'N04-1029': {'paper_name': ' comparison of two interactive search refinement techniques ',
#   'year': '2004',
#   'authors': ['olga vechtomova', 'murat karamuftuoglu']},
#  'E12-1038': {'paper_name': ' inferring selectional preferences from part-of-speech n-grams ',
#   'year': '2012',
#   'authors': ['hyeju jang', 'jack mostow']},
#  'D09-1137': {'paper_name': ' human-competitive tagging using automatic keyphrase extraction ',
#   'year': '2009',
#   'authors': ['olena medelyan', 'eibe frank', 'ian h. witten']},
#  'P11-1152': {'paper_name': ' integrating history-length interpolation and classes in language modeling ',
#   'year': '2011',
#   'authors': ['hinrich schütze']},
#  'D14-1119': {'paper_name': ' vote prediction on comments in social polls ',
#   'year': '2014',
#   'authors': ['isaac persing', 'vincent ng']},
#  'D12-1044': {'paper_name': ' dynamic programming for higher order parsing of gap-minding trees ',
#   'year': '2012',
#   'authors': ['emily pitler', 'sampath kannan', 'mitchell marcus']},
#  'D13-1134': {'paper_name': ' predicting the resolution of referring expressions from user behavior ',
#   'year': '2013',
#   'authors': ['nikos engonopoulos',
#    'martin villalba',
#    'ivan titov',
#    'alexander koller']},
#  'W15-1824': {'paper_name': ' improving the cross-lingual projection of syntactic dependencies ',
#   'year': '2015',
#   'authors': ['jörg tiedemann']},
#  'D13-1117': {'paper_name': ' feature noising for log-linear structured prediction ',
#   'year': '2013',
#   'authors': ['sida wang',
#    'mengqiu wang',
#    'stefan wager',
#    'percy liang',
#    'christopher d. manning']},
#  'P10-1074': {'paper_name': ' hierarchical joint learning: improving joint parsing and named entity recognition with non-jointly labeled data ',
#   'year': '2010',
#   'authors': ['jenny rose finkel', 'christopher d. manning']},
#  'W10-2926': {'paper_name': ' on reverse feature engineering of syntactic tree kernels ',
#   'year': '2010',
#   'authors': ['daniele pighin', 'alessandro moschitti']},
#  'P10-1013': {'paper_name': ' open information extraction using wikipedia ',
#   'year': '2010',
#   'authors': ['fei wu', 'daniel s. weld']},
#  'J05-4002': {'paper_name': ' co-occurrence retrieval: a flexible framework for lexical distributional similarity ',
#   'year': '2005',
#   'authors': ['julie weeds and david weir']},
#  'Q14-1003': {'paper_name': ' automatic detection and language identification of multilingual documents ',
#   'year': '2014',
#   'authors': []},
#  'P10-1011': {'paper_name': ' bilingual lexicon generation using non-aligned signatures ',
#   'year': '2010',
#   'authors': ['daphna shezaf', 'ari rappoport']},
#  'W06-1631': {'paper_name': ' capturing out-of-vocabulary words in arabic text ',
#   'year': '2006',
#   'authors': ['abdusalam f.a. nwesri', 's.m.m. tahaghoghi', 'falk scholer']},
#  'D12-1006': {'paper_name': ' detecting subgroups in online discussions by modeling positive and negative relations among participants ',
#   'year': '2012',
#   'authors': ['ahmed hassan', 'amjad abu-jbara', 'dragomir radev']},
#  'W08-2104': {'paper_name': ' linguistic features in data-driven dependency parsing ',
#   'year': '2008',
#   'authors': ['lilja ovrelid']},
#  'N13-1011': {'paper_name': ' cross-lingual semantic similarity of words as the similarity of their semantic word responses ',
#   'year': '2013',
#   'authors': ['ivan vulić', 'marie-francine moens']},
#  'P10-1065': {'paper_name': ' on jointly recognizing and aligning bilingual named entities ',
#   'year': '2010',
#   'authors': ['yufeng chen', 'chengqing zong', 'keh-yih su']},
#  'D11-1031': {'paper_name': ' training a log-linear parser with loss functions via softmax-margin ',
#   'year': '2011',
#   'authors': ['michael auli', 'adam lopez']},
#  'W03-0402': {'paper_name': ' an svm based voting algorithm with application to parse reranking ',
#   'year': '2003',
#   'authors': ['libin shen', 'aravind k. joshi']},
#  'P10-1090': {'paper_name': ' convolution kernel over packed parse forest ',
#   'year': '2010',
#   'authors': ['min zhang', 'hui zhang', 'haizhou li']},
#  'E09-1057': {'paper_name': ' language-independent bilingual terminology extraction from a multilingual parallel corpus ',
#   'year': '2009',
#   'authors': ['els lefever', 'lieve macken', 'veronique hoste']},
#  'W05-0610': {'paper_name': ' using uneven margins svm and perceptron for information extraction ',
#   'year': '2005',
#   'authors': ['yaoyong li', 'kalina bontcheva', 'hamish cunningham']},
#  'P05-1035': {'paper_name': ' qarla:a framework for the evaluation of text summarization systems ',
#   'year': '2005',
#   'authors': ['enrique amigó',
#    'julio gonzalo',
#    'anselmo peñas',
#    'felisa verdejo']},
#  'P10-1159': {'paper_name': ' automated planning for situated natural language generation ',
#   'year': '2010',
#   'authors': ['konstantina garoufi', 'alexander koller']},
#  'P14-1048': {'paper_name': ' a linear-time bottom-up discourse parser with constraints and post-editing ',
#   'year': '2014',
#   'authors': []},
#  'D13-1018': {'paper_name': ' growing multi-domain glossaries from a few seeds using probabilistic topic models ',
#   'year': '2013',
#   'authors': ['stefano faralli', 'roberto navigli']},
#  'D08-1005': {'paper_name': ' one-class clustering in the text domain ',
#   'year': '2008',
#   'authors': ['ron bekkerman', 'koby crammer']},
#  'N12-1045': {'paper_name': ' a hierarchical dirichlet process model for joint part-of-speech and morphology induction ',
#   'year': '2012',
#   'authors': ['kairit sirts', 'tanel alumäe']},
#  'J94-4001': {'paper_name': ' a syntactic analysis method of long japanese sentences based on the detection of conjunctive structures ',
#   'year': '1994',
#   'authors': ['sadao kurohashi', 'makoto nagao']},
#  'D09-1115': {'paper_name': ' lattice-based system combination for statistical machine translation ',
#   'year': '2009',
#   'authors': ['yang feng', 'yang liu', 'haitao mi', 'qun liu', 'yajuan lü']},
#  'D14-1222': {'paper_name': ' a rule-based system for unrestricted bridging resolution: recognizing bridging anaphora and finding links to antecedents ',
#   'year': '2014',
#   'authors': ['yufang hou', 'katja markert', 'michael strube']},
#  'N06-1007': {'paper_name': ' acquisition of verb entailment from text ',
#   'year': '2006',
#   'authors': []},
#  'E06-1026': {'paper_name': ' latent variable models for semantic orientations of phrases ',
#   'year': '2006',
#   'authors': []},
#  'K15-1004': {'paper_name': ' a synchronous hyperedge replacement grammar based approach for amr parsing ',
#   'year': '2015',
#   'authors': ['xiaochang peng', 'linfeng song', 'daniel gildea']},
#  'P98-1090': {'paper_name': ' long distance pronominalisation and global focus ',
#   'year': '1998',
#   'authors': ['janet hitzeman', 'massimo poesio']},
#  'W06-2906': {'paper_name': ' resolving and generating definite anaphora by modeling hypernymy using unlabeled corpora ',
#   'year': '2006',
#   'authors': ['nikesh garera', 'david yarowsky']},
#  'E14-1078': {'paper_name': ' learning part-of-speech taggers with inter-annotator agreement loss ',
#   'year': '2014',
#   'authors': ['barbara plank', 'dirk hovy', 'anders søgaard']},
#  'Q15-1011': {'paper_name': ' entity disambiguation with web links ',
#   'year': '2015',
#   'authors': ['andrew chisholm', 'ben hachey']},
#  'D14-1021': {'paper_name': ' syntactic smt using a discriminative text generation model ',
#   'year': '2014',
#   'authors': ['yue zhang',
#    'kai song',
#    'linfeng song',
#    'jingbo zhu',
#    'qun liu']},
#  'P14-1138': {'paper_name': ' recurrent neural networks for word alignment model ',
#   'year': '2014',
#   'authors': []},
#  'N12-1017': {'paper_name': ' hyter: meaning-equivalent semantics for translation evaluation ',
#   'year': '2012',
#   'authors': ['markus dreyer', 'daniel marcu']},
#  'E14-1039': {'paper_name': ' fast statistical parsing with parallel multiple context-free grammars ',
#   'year': '2014',
#   'authors': ['krasimir angelov', 'peter ljunglöf']},
#  'N03-1002': {'paper_name': ' japanese named entity extraction with redundant morphological analysis ',
#   'year': '2003',
#   'authors': ['masayuki asahara', 'yuji matsumoto']},
#  'D11-1108': {'paper_name': ' learning sentential paraphrases from bilingual parallel corpora for text-to-text generation ',
#   'year': '2011',
#   'authors': ['juri ganitkevitch',
#    'chris callison-burch',
#    'courtney napoles',
#    'benjamin van durme']},
#  'N06-1031': {'paper_name': ' relabeling syntax trees to improve syntax-based machine translation quality ',
#   'year': '2006',
#   'authors': []},
#  'P12-1045': {'paper_name': ' fast online lexicon learning for grounded language acquisition ',
#   'year': '2012',
#   'authors': ['david chen']},
#  'N13-1003': {'paper_name': ' improved reordering for phrase-based translation using sparse features ',
#   'year': '2013',
#   'authors': ['colin cherry']},
#  'Q15-1005': {'paper_name': ' a sense-topic model for word sense induction with unsupervised data enrichment ',
#   'year': '2015',
#   'authors': ['jing wang',
#    'mohit bansal',
#    'kevin gimpel',
#    'brian d. ziebart',
#    'clement t. yu']},
#  'D13-1105': {'paper_name': ' automatic extraction of morphological lexicons from morphologically annotated corpora ',
#   'year': '2013',
#   'authors': ['ramy eskander', 'nizar habash', 'owen rambow']},
#  'D15-1011': {'paper_name': ' system combination for multi-document summarization ',
#   'year': '2015',
#   'authors': ['kai hong', 'mitchell marcus', 'ani nenkova']},
#  'P14-1108': {'paper_name': ' paul georg wagner and till speicher ',
#   'year': '2014',
#   'authors': []},
#  'D14-1063': {'paper_name': ' translation rules with right-hand side lattices ',
#   'year': '2014',
#   'authors': ['fabien cromieres', 'sadao kurohashi']},
#  'P09-1066': {'paper_name': ' collaborative decoding: partial hypothesis re-ranking using translation consensus between decoders ',
#   'year': '2009',
#   'authors': ['mu li',
#    'nan duan',
#    'dongdong zhang',
#    'chi-ho li',
#    'ming zhou']},
#  'P15-1031': {'paper_name': ' an effective neural network model for graph-based dependency parsing ',
#   'year': '2015',
#   'authors': ['wenzhe pei', 'tao ge', 'baobao chang']},
#  'P15-1102': {'paper_name': ' co-training for semi-supervised sentiment classification based on dual-view bags-of-words representation ',
#   'year': '2015',
#   'authors': ['rui xia', 'cheng wang', 'xin-yu dai', 'tao li']},
#  'N10-1015': {'paper_name': ' joint parsing and alignment with weakly synchronized grammars ',
#   'year': '2010',
#   'authors': ['david burkett', 'john blitzer', 'dan klein']},
#  'E03-1053': {'paper_name': ' language independent authorship attribution using character level language models ',
#   'year': '2003',
#   'authors': ['fuchun peng',
#    'dale schuurmans',
#    'vlado keselj',
#    'shaojun wang']},
#  'J95-4002': {'paper_name': ' tree insertion grammar: a cubic-time, parsable formalism that lexicalizes context-free grammar without changing the trees produced ',
#   'year': '1995',
#   'authors': ['yves schabes', 'richard c. waters']},
#  'D08-1099': {'paper_name': ' automatic set expansion for list question answering ',
#   'year': '2008',
#   'authors': ['richard c. wang',
#    'nico schlaefer',
#    'william w. cohen',
#    'eric nyberg']},
#  'P06-1054': {'paper_name': ' a fast, accurate deterministic parser for chinese ',
#   'year': '2006',
#   'authors': ['mengqiu wang', 'kenji sagae', 'teruko mitamura']},
#  'P92-1006': {'paper_name': ' efficiency, robustness and accuracy in picky chart parsing* ',
#   'year': '1992',
#   'authors': ['david m. magerman', 'carl weir']},
#  'N12-1009': {'paper_name': ' reference scope identification in citing sentences ',
#   'year': '2012',
#   'authors': ['amjad abu jbara', 'dragomir radev']},
#  'D12-1042': {'paper_name': ' multi-instance multi-label learning for relation extraction ',
#   'year': '2012',
#   'authors': ['mihai surdeanu',
#    'julie tibshirani',
#    'ramesh nallapati',
#    'christopher d. manning']},
#  'D15-1159': {'paper_name': ' improved transition-based parsing and tagging with neural networks ',
#   'year': '2015',
#   'authors': ['chris alberti', 'david weiss', 'greg coppola', 'slav petrov']},
#  'P06-1098': {'paper_name': ' left-to-right target generation for hierarchical phrase-based translation ',
#   'year': '2006',
#   'authors': ['taro watanabe', 'hajime tsukada', 'hideki isozaki']},
#  'P10-1020': {'paper_name': ' entity-based local coherence modelling using topological fields ',
#   'year': '2010',
#   'authors': ['jackie chi kit cheung', 'gerald penn']},
#  'N13-1135': {'paper_name': ' a participant-based approach for event summarization using twitter streams ',
#   'year': '2013',
#   'authors': ['chao shen', 'fei liu', 'fuliang weng', 'tao li']},
#  'P04-1056': {'paper_name': ' collective information extraction with relational markov networks ',
#   'year': '2004',
#   'authors': ['razvan bunescu', 'raymond mooney']},
#  'D08-1022': {'paper_name': ' forest-based translation rule extraction ',
#   'year': '2008',
#   'authors': ['haitao mi', 'liang huang']},
#  'D15-1310': {'paper_name': ' twitter-scale new event detection via k-term hashing ',
#   'year': '2015',
#   'authors': ['dominik wurzer', 'victor lavrenko', 'miles osborne']},
#  'P12-1075': {'paper_name': ' unsupervised relation discovery with sense disambiguation ',
#   'year': '2012',
#   'authors': ['limin yao', 'sebastian riedel', 'andrew mccallum']},
#  'A00-1019': {'paper_name': ' unit completion for a computer-aided translation typing system ',
#   'year': '2000',
#   'authors': ['philippe langlais', 'george foster', 'guy lapalme']},
#  'D13-1089': {'paper_name': ' scaling to large3 data: an efficient and effective method to compute distributional thesauri ',
#   'year': '2013',
#   'authors': ['martin riedl', 'chris biemann']},
#  'W14-4343': {'paper_name': ' the sjtu system for dialog state tracking challenge 2 ',
#   'year': '2014',
#   'authors': []},
#  'D15-1241': {'paper_name': ' knowledge base inference using bridging entities ',
#   'year': '2015',
#   'authors': ['bhushan kotnis', 'pradeep bansal', 'partha p. talukdar']},
#  'P00-1022': {'paper_name': ' a computational approach to zero-pronouns in spanish ',
#   'year': '2000',
#   'authors': ['antonio ferrández', 'jesús peral']},
#  'D14-1218': {'paper_name': ' a model of coherence based on distributed sentence representation ',
#   'year': '2014',
#   'authors': ['jiwei li', 'eduard hovy']},
#  'J07-1003': {'paper_name': ' word-level confidence estimation for machine translation ',
#   'year': '2007',
#   'authors': ['nicola ueffing', 'hermann ney']},
#  'P98-2237': {'paper_name': ' using chunk based partial parsing of spontaneous speech in unrestricted domains for reducing word error rate in speech recognition ',
#   'year': '1998',
#   'authors': ['klaus zechner', 'alex waibel']},
#  'D13-1034': {'paper_name': ' adaptor grammars for learning non-concatenative morphology ',
#   'year': '2013',
#   'authors': ['jan a. botha', 'phil blunsom']},
#  'A00-2025': {'paper_name': ' minimizing word error rate in textual summaries of spoken language ',
#   'year': '2000',
#   'authors': ['klaus zechner', 'alex waibel']},
#  'P13-1010': {'paper_name': ' graph-based local coherence modeling ',
#   'year': '2013',
#   'authors': ['camille guinaudeau', 'michael strube']},
#  'D15-1015': {'paper_name': ' visual bilingual lexicon induction with transferred convnet features ',
#   'year': '2015',
#   'authors': ['douwe kiela', 'ivan vulić', 'stephen clark']},
#  'Q13-1024': {'paper_name': ' large-scale word alignment using soft dependency cohesion constraints ',
#   'year': '2013',
#   'authors': []},
#  'D13-1144': {'paper_name': ' a walk-based semantically enriched tree kernel over distributed word representations ',
#   'year': '2013',
#   'authors': ['shashank srivastava', 'dirk hovy', 'eduard hovy']},
#  'P06-1113': {'paper_name': ' question answering with lexical chains propagating verb arguments ',
#   'year': '2006',
#   'authors': ['adrian novischi', 'dan moldovan']},
#  'P93-1035': {'paper_name': ' automatic grammar induction and parsing free text: a transformation-based approach ',
#   'year': '1993',
#   'authors': ['eric brill']},
#  'E12-1062': {'paper_name': ' learning for microblogs with distant supervision: political forecasting with twitter ',
#   'year': '2012',
#   'authors': ['micol marchetti-bowick', 'nathanael chambers']},
#  'D14-1225': {'paper_name': ' prune-and-score: learning for greedy coreference resolution ',
#   'year': '2014',
#   'authors': ['chao ma',
#    'janardhan rao doppa',
#    'j. walker orr',
#    'prashanth mannem',
#    'xiaoli fern',
#    'tom dietterich',
#    'prasad tadepalli']},
#  'D09-1001': {'paper_name': ' unsupervised semantic parsing ',
#   'year': '2009',
#   'authors': ['hoifung poon', 'pedro domingos']},
#  'D14-1085': {'paper_name': ' unsupervised sentence enhancement for automatic summarization ',
#   'year': '2014',
#   'authors': ['jackie chi kit cheung', 'gerald penn']},
#  'J08-1001': {'paper_name': ' modeling local coherence: an entity-based approach ',
#   'year': '2008',
#   'authors': ['regina barzilay', 'mirella lapata']},
#  'P06-1038': {'paper_name': ' efficient unsupervised discovery of word categories using symmetric patterns and high frequency words ',
#   'year': '2006',
#   'authors': ['dmitry davidov', 'ari rappoport']},
#  'K15-1026': {'paper_name': ' symmetric pattern based word embeddings for improved word similarity prediction ',
#   'year': '2015',
#   'authors': ['roy schwartz', 'roi reichart', 'ari rappoport']},
#  'D15-1025': {'paper_name': ' non-lexical neural architecture for fine-grained pos tagging ',
#   'year': '2015',
# ...
#   'authors': ['yee seng chan', 'hwee tou ng']},
#  'J01-2002': {'paper_name': ' improving accuracy in word class tagging through the combination of machine learning systems ',
#   'year': '2001',
#   'authors': ['hans van halteren', 'walter daelemans', 'jakub zavrel']},
#  'P09-1016': {'paper_name': ' transliteration alignment ',
#   'year': '2009',
#   'authors': ['vladimir pervouchine', 'haizhou li', 'bo lin']},
#  'E14-1064': {'paper_name': ' bilingual sentiment consistency for statistical machine translation ',
#   'year': '2014',
#   'authors': ['boxing chen', 'xiaodan zhu']},
#  'P03-1026': {'paper_name': ' a tabulation-based parsing method that reduces copying ',
#   'year': '2003',
#   'authors': ['gerald penn', 'cosmin munteanu']},
#  'P10-1017': {'paper_name': ' hierarchical search for word alignment ',
#   'year': '2010',
#   'authors': ['jason riesa', 'daniel marcu']},
#  'E06-1005': {'paper_name': ' computing consensus translation from multiple machine translation systems using enhanced hypotheses alignment ',
#   'year': '2006',
#   'authors': []},
#  'D12-1058': {'paper_name': ' enlarging paraphrase collections through generalization and instantiation ',
#   'year': '2012',
#   'authors': ['atsushi fujita', 'pierre isabelle', 'roland kuhn']},
#  'W04-2403': {'paper_name': ' a semantic kernel for predicate argument classification ',
#   'year': '2004',
#   'authors': ['alessandro moschitti', 'cosmin adrian bejan']},
#  'J15-2004': {'paper_name': ' a statistical parsing framework for sentiment classification ',
#   'year': '2015',
#   'authors': ['li dong', 'furu wei', 'shujie liu', 'ming zhou', 'ke xu']},
#  'P03-1003': {'paper_name': ' a noisy-channel approach to question answering ',
#   'year': '2003',
#   'authors': ['abdessamad echihabi', 'daniel marcu']},
#  'W06-1659': {'paper_name': ' unsupervised information extraction approach using graph mutual reinforcement ',
#   'year': '2006',
#   'authors': ['hany hassan', 'ahmed hassan', 'ossama emam']},
#  'A00-2040': {'paper_name': ' a finite state and data-oriented method for grapheme to phoneme conversion ',
#   'year': '2000',
#   'authors': ['gosse bouma']},
#  'N13-1090': {'paper_name': ' linguistic regularities in continuous space word representations ',
#   'year': '2013',
#   'authors': ['tomas mikolov', 'wen-tau yih', 'geoffrey zweig']},
#  'D14-1004': {'paper_name': ' a neural network approach to selectional preference acquisition ',
#   'year': '2014',
#   'authors': ['tim van de cruys']},
#  'K15-1024': {'paper_name': ' recovering traceability links in requirements documents ',
#   'year': '2015',
#   'authors': ['zeheng li', 'mingrui chen', 'liguo huang', 'vincent ng']},
#  'E12-1013': {'paper_name': ' computing lattice bleu oracle scores for machine translation ',
#   'year': '2012',
#   'authors': ['artem sokolov', 'guillaume wisniewski', 'francois yvon']},
#  'P06-1116': {'paper_name': ' a bootstrapping approach to unsupervised detection of cue phrase variants ',
#   'year': '2006',
#   'authors': ['rashid m. abdalla', 'simone teufel']},
#  'E09-1035': {'paper_name': ' structural, transitive and latent models for biographic fact extraction ',
#   'year': '2009',
#   'authors': ['nikesh garera', 'david yarowsky']},
#  'D12-1017': {'paper_name': ' local and global context for supervised and unsupervised metonymy resolution ',
#   'year': '2012',
#   'authors': ['vivi nastase',
#    'alex judea',
#    'katja markert',
#    'michael strube']},
#  'P96-1006': {'paper_name': ' integrating multiple knowledge sources to disambiguate word sense: an exemplar-based approach ',
#   'year': '1996',
#   'authors': ['hwee tou ng', 'hian beng lee']},
#  'D13-1041': {'paper_name': ' efficient collective entity linking with stacking ',
#   'year': '2013',
#   'authors': ['zhengyan he',
#    'shujie liu',
#    'yang song',
#    'mu li',
#    'ming zhou',
#    'houfeng wang']},
#  'N13-1023': {'paper_name': ' segmentation strategies for streaming speech translation ',
#   'year': '2013',
#   'authors': ['vivek kumar rangarajan sridhar',
#    'john chen',
#    'srinivas bangalore',
#    'andrej ljolje',
#    'rathinavelu chengalvarayan']},
#  'P12-1022': {'paper_name': ' discriminative strategies to integrate multiword expression recognition and parsing ',
#   'year': '2012',
#   'authors': ['matthieu constant', 'anthony sigogne', 'patrick watrin']},
#  'W03-1015': {'paper_name': ' bootstrapping coreference classifiers with multiple machine learning algorithms ',
#   'year': '2003',
#   'authors': ['vincent ng', 'claire cardie']},
#  'P94-1025': {'paper_name': ' part-of-speech tagging using a variable memory markov model ',
#   'year': '1994',
#   'authors': ['hinrich schuetze', 'yoram singer']},
#  'P12-1084': {'paper_name': ' collective classification for fine-grained information status ',
#   'year': '2012',
#   'authors': ['katja markert', 'yufang hou', 'michael strube']},
#  'D08-1021': {'paper_name': ' syntactic constraints on paraphrases extracted from parallel corpora ',
#   'year': '2008',
#   'authors': ['chris callison-burch']},
#  'D15-1019': {'paper_name': ' learning to recognize affective polarity in similes ',
#   'year': '2015',
#   'authors': ['ashequl qadir', 'ellen riloff', 'marilyn walker']},
#  'P15-1041': {'paper_name': ' learning to adapt credible knowledge in cross-lingual sentiment analysis ',
#   'year': '2015',
#   'authors': ['qiang chen', 'wenjie li', 'yu lei', 'xule liu', 'yanxiang he']},
#  'D14-1037': {'paper_name': ' a graph-based approach for contextual text normalization ',
#   'year': '2014',
#   'authors': ['cagil sonmez', 'arzucan ozgur']},
#  'P11-1089': {'paper_name': ' a discriminative model for joint morphological disambiguation and dependency parsing ',
#   'year': '2011',
#   'authors': ['john lee', 'jason naradowsky', 'david a. smith']},
#  'P11-1144': {'paper_name': ' semi-supervised frame-semantic parsing for unknown predicates ',
#   'year': '2011',
#   'authors': ['dipanjan das', 'noah a. smith']},
#  'N09-1010': {'paper_name': ' adding more languages improves unsupervised multilingual part-of-speech tagging: a bayesian non-parametric approach ',
#   'year': '2009',
#   'authors': ['benjamin snyder',
#    'tahira naseem',
#    'jacob eisenstein',
#    'regina barzilay']},
#  'W06-1640': {'paper_name': ' partially supervised coreference resolution for opinion summarization through structured rule learning ',
#   'year': '2006',
#   'authors': ['veselin stoyanov', 'claire cardie']},
#  'D12-1022': {'paper_name': ' multiple aspect summarization using integer linear programming ',
#   'year': '2012',
#   'authors': ['kristian woodsend', 'mirella lapata']},
#  'P06-1144': {'paper_name': ' multilingual document clustering: an heuristic approach based on cognate named entities ',
#   'year': '2006',
#   'authors': ['soto montalvo',
#    'raquel martínez',
#    'arantza casillas',
#    'víctor fresno']},
#  'P06-1072': {'paper_name': ' annealing structural bias in multilingual weighted grammar induction* ',
#   'year': '2006',
#   'authors': ['noah a. smith', 'jason eisner']},
#  'D14-1205': {'paper_name': ' joint inference for knowledge base population ',
#   'year': '2014',
#   'authors': ['liwei chen',
#    'yansong feng',
#    'jinghui mo',
#    'songfang huang',
#    'dongyan zhao']},
#  'P13-1130': {'paper_name': ' language acquisition and probabilistic models: keeping it simple ',
#   'year': '2013',
#   'authors': ['aline villavicencio',
#    'marco idiart',
#    'robert berwick',
#    'igor malioutov']},
#  'P08-1027': {'paper_name': ' classification of semantic relationships between nominals using pattern clusters ',
#   'year': '2008',
#   'authors': ['dmitry davidov', 'ari rappoport']},
#  'P09-1070': {'paper_name': ' latent variable models of concept-attribute attachment ',
#   'year': '2009',
#   'authors': ['joseph reisinger', 'marius pasca']},
#  'D15-1031': {'paper_name': ' aligning knowledge and text embeddings by entity descriptions ',
#   'year': '2015',
#   'authors': ['huaping zhong',
#    'jianwen zhang',
#    'zhen wang',
#    'hai wan',
#    'zheng chen']},
#  'D14-1194': {'paper_name': ' #tagspace: semantic embeddings from hashtags ',
#   'year': '2014',
#   'authors': ['jason weston', 'sumit chopra', 'keith adams']},
#  'D10-1028': {'paper_name': ' modeling perspective using adaptor grammars ',
#   'year': '2010',
#   'authors': []},
#  'N09-1045': {'paper_name': ' improving the arabic pronunciation dictionary for phone and word recognition with linguistically-based pronunciation rules ',
#   'year': '2009',
#   'authors': ['fadi biadsy', 'nizar habash', 'julia hirschberg']},
#  'Q15-1010': {'paper_name': ' unsupervised declarative knowledge induction for constraint-based learning of information structure in scientific documents ',
#   'year': '2015',
#   'authors': ['yufan guo', 'roi reichart', 'anna korhonen']},
#  'W04-3248': {'paper_name': ' a new approach for english-chinese named entity alignment ',
#   'year': '2004',
#   'authors': ['donghui  feng', 'yajuan  lv', 'ming  zhou']},
#  'N13-1080': {'paper_name': ' what’s in a domain? multi-domain learning for multi-attribute data ',
#   'year': '2013',
#   'authors': ['mahesh joshi',
#    'mark dredze',
#    'william w. cohen',
#    'carolyn p. rosé']},
#  'P15-1015': {'paper_name': ' learning dynamic feature selection for fast sequential prediction ',
#   'year': '2015',
#   'authors': ['emma strubell',
#    'luke vilnis',
#    'kate silverstein',
#    'andrew mccallum']},
#  'W15-4924': {'paper_name': ' word alignment based parallel corpora evaluation and cleaning using machine learning techniques ',
#   'year': '2015',
#   'authors': ['ieva zariņa', 'pēteris ņikiforovs', 'raivis skadiņš']},
#  'D13-1136': {'paper_name': ' connecting language and knowledge bases with embedding models for relation extraction ',
#   'year': '2013',
#   'authors': ['jason weston',
#    'antoine bordes',
#    'oksana yakhnenko',
#    'nicolas usunier']},
#  'P15-1113': {'paper_name': ' transition-based neural constituent parsing ',
#   'year': '2015',
#   'authors': ['taro watanabe', 'eiichiro sumita']},
#  'P06-1102': {'paper_name': ' names and similarities on the web: fact extraction in the fast lane ',
#   'year': '2006',
#   'authors': ['marius paşca',
#    'dekang lin',
#    'jeffrey bigham',
#    'andrei lifchits',
#    'alpa jain']},
#  'W06-1607': {'paper_name': ' phrasetable smoothing for statistical machine translation ',
#   'year': '2006',
#   'authors': ['george foster', 'roland kuhn', 'howard johnson']},
#  'D15-1028': {'paper_name': ' modeling tweet arrival times using log-gaussian cox processes ',
#   'year': '2015',
#   'authors': ['michal lukasik',
#    'p. k. srijith',
#    'trevor cohn',
#    'kalina bontcheva']},
#  'S15-1003': {'paper_name': ' a hybrid distributional and knowledge-based model of lexical semantics ',
#   'year': '2015',
#   'authors': []},
#  'D09-1052': {'paper_name': ' multi-class confidence weighted algorithms ',
#   'year': '2009',
#   'authors': ['koby crammer', 'mark dredze', 'alex kulesza']},
#  'W09-1106': {'paper_name': ' efficient linearization of tree kernel functions ',
#   'year': '2009',
#   'authors': ['daniele pighin', 'alessandro moschitti']},
#  'N06-1015': {'paper_name': ' word alignment via quadratic assignment ',
#   'year': '2006',
#   'authors': []},
#  'P03-1046': {'paper_name': ' parsing with generative models of predicate-argument structure ',
#   'year': '2003',
#   'authors': ['julia  hockenmaier']},
#  'N10-1005': {'paper_name': ' appropriately handled prosodic breaks help pcfg parsing ',
#   'year': '2010',
#   'authors': ['zhongqiang huang', 'mary harper']},
#  'D14-1003': {'paper_name': ' translation modeling with bidirectional recurrent neural networks ',
#   'year': '2014',
#   'authors': ['martin sundermeyer',
#    'tamer alkhouli',
#    'joern wuebker',
#    'hermann ney']},
#  'D13-1022': {'paper_name': ' optimal beam search for machine translation ',
#   'year': '2013',
#   'authors': ['alexander rush', 'yin-wen chang', 'michael collins']},
#  'W04-2408': {'paper_name': ' a fisher kernel based on plsi ',
#   'year': '2004',
#   'authors': ['hiroya takamura', 'yuji matsumoto', 'hiroyasu yamada']},
#  'J81-3002': {'paper_name': ' translating spanish into logic through logic ',
#   'year': '1981',
#   'authors': ['veronica dahl']},
#  'E06-1021': {'paper_name': ' towards robust context-sensitive sentence alignment for monolingual corpora ',
#   'year': '2006',
#   'authors': []},
#  'P15-1061': {'paper_name': ' classifying relations by ranking with convolutional neural networks ',
#   'year': '2015',
#   'authors': ['cicero dos santos', 'bing xiang', 'bowen zhou']},
#  'E99-1026': {'paper_name': ' japanese dependency structure analysis based on maximum entropy models ',
#   'year': '1999',
#   'authors': ['kiyotaka uchimoto', 'satoshi sekine', 'hitoshi isahara']},
#  'D14-1192': {'paper_name': ' a model of individual differences in gaze control during reading ',
#   'year': '2014',
#   'authors': ['niels landwehr',
#    'sebastian arzt',
#    'tobias scheffer',
#    'reinhold kliegl']},
#  'P05-1024': {'paper_name': ' boosting-based parse reranking with subtree features ',
#   'year': '2005',
#   'authors': ['taku kudo', 'jun suzuki', 'hideki isozaki']},
#  'D12-1013': {'paper_name': ' active learning for imbalanced sentiment classification ',
#   'year': '2012',
#   'authors': ['shoushan li', 'shengfeng ju', 'guodong zhou', 'xiaojun li']},
#  'P10-1111': {'paper_name': ' hard constraints for grammatical function labelling ',
#   'year': '2010',
#   'authors': ['wolfgang seeker',
#    'ines rehbein',
#    'jonas kuhn',
#    'josef van genabith']},
#  'D15-1027': {'paper_name': ' a model of zero-shot learning of spoken language understanding ',
#   'year': '2015',
#   'authors': ['majid yazdani', 'james henderson']},
#  'P01-1065': {'paper_name': ' a generic approach to parallel chart parsing with an application to lingo ',
#   'year': '2001',
#   'authors': []},
#  'E97-1063': {'paper_name': ' a word-to-word model of translational equivalence ',
#   'year': '1997',
#   'authors': ['i. dan melamed']},
#  'J10-4006': {'paper_name': ' distributional memory: a general framework for corpus-based semantics ',
#   'year': '2010',
#   'authors': ['marco baroni', 'alessandro lenci']},
#  'D09-1074': {'paper_name': ' discriminative corpus weight estimation for machine translation ',
#   'year': '2009',
#   'authors': ['spyros matsoukas', 'antti-veikko i. rosti', 'bing zhang']},
#  'P14-1011': {'paper_name': ' bilingually-constrained phrase embeddings for machine translation ',
#   'year': '2014',
#   'authors': []},
#  'D15-1135': {'paper_name': ' automatically solving number word problems by semantic parsing and reasoning ',
#   'year': '2015',
#   'authors': ['shuming shi',
#    'yuehui wang',
#    'chin-yew lin',
#    'xiaojiang liu',
#    'yong rui']},
#  'P13-1017': {'paper_name': ' vk vtna * ',
#   'year': '2013',
#   'authors': ['nan yang', 'shujie liu', 'mu li', 'ming zhou', 'nenghai yu']},
#  'D13-1083': {'paper_name': ' a corpus level mira tuning strategy for machine translation ',
#   'year': '2013',
#   'authors': ['ming tan', 'tian xia', 'shaojun wang', 'bowen zhou']},
#  'K15-1006': {'paper_name': ' an iterative similarity based adaptation technique for cross domain text classification ',
#   'year': '2015',
#   'authors': ['himanshu sharad bhatt', 'deepali semwal', 'shourya roy']},
#  'D09-1108': {'paper_name': ' fast translation rule matching for syntax-based statistical machine translation ',
#   'year': '2009',
#   'authors': ['hui zhang', 'min zhang', 'haizhou li', 'chew lim tan']},
#  'P13-1128': {'paper_name': ' entity linking for tweets ',
#   'year': '2013',
#   'authors': ['xiaohua liu',
#    'yitong li',
#    'haocheng wu',
#    'ming zhou',
#    'furu wei',
#    'yi lu']},
#  'N10-1016': {'paper_name': ' learning translation boundaries for phrase-based decoding ',
#   'year': '2010',
#   'authors': ['deyi xiong', 'min zhang', 'haizhou li']},
#  'D14-1139': {'paper_name': ' weakly-supervised learning with cost-augmented contrastive estimation ',
#   'year': '2014',
#   'authors': ['kevin gimpel', 'mohit bansal']},
#  'E12-1025': {'paper_name': ' active learning for interactive machine translation ',
#   'year': '2012',
#   'authors': ['jesús gonzález-rubio',
#    'daniel ortiz-martínez',
#    'francisco casacuberta']},
#  'D12-1001': {'paper_name': ' syntactic transfer using a bilingual lexicon ',
#   'year': '2012',
#   'authors': ['greg durrett', 'adam pauls', 'dan klein']},
#  ...}

# %%
pickle.dump(paper_tits, open("pickles_data/acl_titles_year_auth.pkl","wb"))

# %%
f = open("acl_paper_titles.txt", "w") 
for key in paper_titles :
    name = paper_titles[key]
    if(len(name)>0) :
        f.write(name.lower().replace("\n", " ")+"\n")

# %%
def get_cue_count(words) :
    cue_word_list = ['among', 'precis', 'implement', 'maximum', 'experi', 'strategi', 'overal', 'previou', 'correl', 'calcul', 'achiev', 'gold', 'top', 'obtain', 'significantli', 'report', 'best', 'evalu', 'result', 'base', 'modifi', 'extend', 'metric', 'baselin', 'accord', 'perform', 'model', 'recal', 'standard', 'figur', 'comparison', 'yield', 'outperform', 'increas', 'stateoftheart', 'accuraci', 'method', 'procedur', 'score', 'origin', 'highest', 'signific', 'higher', 'fscore', 'compar']
    count = 0
    for word in words :
        if(word in cue_word_list) :
            count+=1
    return count

# %%
def get_citation_titles(citation_list) :
    citation_titles = {}
    for id in citation_list.keys() :
        citations = citation_list[id]
        titles = []
        for cit in citations :
            title = cit['title']
            titles.append(title)
        citation_titles[id] = titles
    return citation_titles

# %%
def get_overlap(citation_titles, names) :
    dataset = {}
    ids = names.keys()
    for key in citation_titles.keys() :
        paper_title = names[key]
        list_val = []
        for paper in citation_titles[key] :
            overlap = find_common_words(paper_title, paper)
            dict1 = {}
            dict1['paper_name'] = paper
            dict1['overlap'] = overlap
            list_val.append(dict1)
        dataset[key] = list_val
    return dataset

# %%
citations = get_citations("xmls/")
# cit_titles = get_citation_titles(citations)

# %%
popularity = get_popularity_feat(citations)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100

# %%
pickle.dump(popularity[1], open("pickles_data/popularity_sent.pkl", "wb"))

# %%
pickle.dump(cit_titles, open("pickles_data/citation_titles.pkl", "wb"))

# %%
paper_titles = get_paper_titles("xmls/")

# %%
def get_year_difference(citations) :
    dataset = {}
    count = 0
    count1 = 0
    sum1 = 0
    numb = 0
    for key in citations.keys() :
        count_list = []
        try :
            tree = ET.parse("../Data/titles/"+key[0]+"/"+key[:3]+"/"+key[:3]+".xml")
            root = tree.getroot()
            for element in root.iterfind("paper"):
                if(element.attrib['id']==key[4:]):
                    paper_year = element.find('year').text.lower()
        except :
            paper_year = ""
            count1+=1
            if(int(key[1:3])>=0 and int(key[1:3])<=20):
                year = "20"+key[1:3]
            else :
                year = "19"+key[1:3]
        for cit in citations[key] :
            dict1 = {}
            dict1['paper_name'] = cit['title']
            dict1['paper_year'] = paper_year
            try :
                dict1['cit_year'] = cit['cit'].find('date').text.lower()
            except :
                year_re =  re.findall(year_regex,cit['cit'].find('rawString').text.lower())
                if(len(year_re)>=1) :
                    year_re_ag = year_re[0]
                    if(len(year_re_ag)>=1) :
                        year = re.findall(year_regex,cit['cit'].find('rawString').text.lower())[0][0]
                        dict1['cit_year'] = year
                    else :
                        dict1['cit_year']=""
                else :
                    dict1['cit_year']=""
                    
            if(dict1['paper_year']!="" and dict1['cit_year']!="") :
                dict1['diff'] = int(dict1['paper_year']) - int(dict1['cit_year'])
                sum1+= dict1['diff']
                numb+= 1
                
            else :
                count+=1
                dict1['diff'] = 7
                
            count_list.append(dict1)
            
        dataset[key] = count_list
        
    print(count)
    return dataset

# %%
def get_section_feature(section_labels, citations):
    dataset = {}
    other_map = {'table_captions':'tables', 'figure_captions':'figures', 'overall':'body'}
    for key in citations.keys() :
        feat_list = []
        for cit in citations[key] :
            data1 = {}
            data1['paper_name'] = cit['title']
            citStrs = list(set([context.get('citStr').lower() for context in cit['cit'].findall('contexts/context')]))
            section_feature = {'experiment':{'body':0, 'figures':0, 'tables':0, 'note':0, 'overall':0}, 'conclusion':{'body':0, 'figures':0, 'tables':0, 'note':0, 'overall':0}, 'discussion':{'body':0, 'figures':0, 'tables':0, 'note':0, 'overall':0}, 'other_sections':{'body':0, 'figures':0, 'tables':0, 'note':0, 'overall':0}, 'related_work':{'body':0, 'figures':0, 'tables':0, 'note':0, 'overall':0}, 'abstract':{'body':0, 'figures':0, 'tables':0, 'note':0, 'overall':0}, 'introduction':{'body':0, 'figures':0, 'tables':0, 'note':0, 'overall':0}}
            for section in section_labels[key]:
                if section=='overall':
                    continue
                for subsection in section_labels[key][section]:
                    text = section_labels[key][section][subsection]
                    for citStr in citStrs:
                        count = text.count(citStr)
                        try:
                            section_feature[section][subsection]+=count
                        except KeyError:
                            section_feature[section][other_map[subsection]]+=count
                        text = text.replace(citStr, '')
            data1['section_feature'] = section_feature
            feat_list.append(data1)
        dataset[key] = feat_list 
    return dataset

# %%
def get_location_feature(sect_feat):
    dataset = {}
    dataset1 = {}
    for key in sect_feat.keys():
        citations = sect_feat[key]
        count_list = []
        count_list1 = []
        for cit in citations :
            dict1 = {}
            dict2 = {}
            dict1['paper_name'] = cit['paper_name']
            dict2['paper_name'] = cit['paper_name']
            dict2['num_table'] = 0
            sect = cit['section_feature']
            data = []
            data1 = []
            sections = list(sect.keys())
            sections.sort()
            for section in sections :
                if(section!='discussion'):
                    subsections = list(sect[section].keys())
                    subsections.sort()
                    count = 0
                    for subsection in subsections :
                        if(subsection!='overall'):
                            count+= sect[section][subsection]
                        if(subsection=='tables'):
                            dict2['num_table']+= sect[section][subsection]  
                            data1.append(sect[section][subsection])
                    data.append(count)
            count_list1.append(dict2)
            dict1['location_feature'] = data
            dict2['table_loc'] = data1
            count_list.append(dict1)
        dataset[key] = count_list  
        dataset1[key] = count_list1
    return dataset,dataset1

# %%
def get_baselines():
    f = open("./annotation/annotations2")
    data = []
    for line in f:
        data.append(line)

    dataset = {}
    for line in data:
        x = line.split("_")
        dataset[x[0]] = x[1:]
        
    f = open("./annotation/django_annotations")
    data = []
    for line in f:
        data.append(line)
        
    for line in data :
        x = line.split("_")
        if(len(x)>1) :
            dataset[x[0]] = x[1:]
            
    df = pd.read_excel("./annotation/Baselines.xlsx")
    ar = []
    for i in range(586) :
        if(df['Baseline Papers'][i]!='None' and type(df['Baseline Papers'][i])!=type(0.1)):
            ar.append(i)
    
    for ind in ar :
        paperId = df['PaperId'][ind]
        if(len(paperId)!=8):
            paperId = paperId[:-1]      
        x = df['Baseline Papers'][ind].split("_")
        
        dataset[paperId] = x
            
    return dataset

# %%
def get_fixed_context(citations):
    dataset = {}
    for key in citations.keys():
        context_list = []
        for cit in citations[key] :
            dict1 = {}
            dict1['paper_name'] = cit['title']
            dict1['fixed_context'] = []
            for context in cit['cit'].findall('contexts/context') :
                words = get_words(context.text.lower())
                if(len(words)==0):
                    dict1['fixed_context'].append(['<citation>'])
                else :
                    a = int(len(words)/2)
                    dict1['fixed_context'].append(words[a-20//2:a+20//2])
            if(len(dict1['fixed_context'])==0):
                dict1['fixed_context'].append(['<citation>'])
            context_list.append(dict1)
        dataset[key] = context_list
        
    return dataset

# %%
def get_contexts(citations) :
    dataset = {}
    count = 0
    for key in citations.keys():
        context_list = []
        for cit in citations[key] :
            dict1 = {}
            dict1['paper_name'] = cit['title']
            dict1['context'] = ""
            for context in cit['cit'].findall('contexts/context') :
                text = context.text.lower()
                citstr = context.get('citStr').lower()
                text = text.replace(citstr, "this_citation")
                dict1['context']+= text+" "
            dict1['context'] = get_words(dict1['context'])
            context_list.append(dict1)
        dataset[key] = context_list
        count+=1
        if(count%100==0) :
            print(count)
    return dataset

# %%
def get_words(string, cit_auths=None):

    string = string.replace('-', '').lower()
    context_words = word_tokenize(string)
    final_context_words = []

    for word in context_words:
        if word in stop_words:
            continue
        if re.fullmatch(year_regex, word): #or match_auths(word, cit_auths):
            continue
        if re.fullmatch(r'[0-9]+([.][0-9]+)?', word):
            word = '<number>'
            final_context_words.append(word)
        elif 'this_citation' in word:
            final_context_words.append('<this_citation>')
        elif re.fullmatch(r'[a-z]+', word):
            original_word = word
            word = lemmatizer.lemmatize(word)
            final_word = stemmer.stem(word)

            if final_word not in conversion_dict:
                conversion_dict[final_word] = {}

            if original_word not in conversion_dict[final_word]:
                conversion_dict[final_word][original_word] = 0
            conversion_dict[final_word][original_word]+=1

            final_context_words.append(final_word)

    return final_context_words

# %%
def get_baseline_tags(baselines, citations):
    dataset = {}
    ids = citations.keys()
    for id in ids :
        cits = citations[id]
        baselist = baselines[id]
        citlist = []
        for cit in cits :
            title = cit['title']
            dict1 = {}
            dict1['paper_name'] = title
            check = 0
            for base in baselines[id] :
                if(match_titles(base, title)):
                    check = 1
                    dict1['tag'] = 1
                    break
            if(check==0) :
                dict1['tag']= 0
            citlist.append(dict1)
        dataset[id] = citlist
    return dataset

# %%
citations = get_citations("xmls_total/")

# %%
paper_titles = get_paper_titles("xmls_total/")

# %%
def get_overlap(citation_titles, names) :
    dataset = {}
    ids = names.keys()
    for key in citation_titles.keys() :
        paper_title = names[key]
        list_val = []
        for paper in citation_titles[key] :
            overlap = find_common_words(paper_title, paper)
            dict1 = {}
            dict1['paper_name'] = paper
            dict1['overlap'] = overlap
            list_val.append(dict1)
        dataset[key] = list_val
    return dataset

# %%
cit_titles = get_citation_titles(citations)
overlap = get_overlap(cit_titles,paper_titles)

# %%
pickle.dump(cit_titles, open("pickles/citation_titles.pkl","wb"))

# %%
pickle.dump(overlap, open("pickles/title_overlap.pkl","wb"))

# %%
section_labels = pickle.load(open("pickles_data/section_labels.pkl", "rb"))

# %%
sect_feat = get_section_feature(section_labels, citations)

# %%
pickle.dump(sect_feat, open("pickles_data/section_feature.pkl","wb"))

# %%
print(len(sect_feat.keys()))
# Out:
# 1181

# %%
loc_feat, num_table = get_location_feature(sect_feat)

# %%
pickle.dump(loc_feat, open("pickles_data/location_feature.pkl","wb"))
pickle.dump(num_table, open("pickles_data/num_table.pkl","wb"))

# %%
contexts = get_contexts(citations)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100

# %%
pickle.dump(contexts, open("pickles_data/context_words.pkl","wb"))

# %%
fixed_context = get_fixed_context(citations)

# %%
pickle.dump(fixed_context, open("pickles_data/fixed_context.pkl","wb"))

# %%
cue_word_list = ['among', 'precis', 'implement', 'maximum', 'experi', 'strategi', 'overal', 'previou', 'correl', 'calcul', 'achiev', 'gold', 'top', 'obtain', 'significantli', 'report', 'best', 'evalu', 'result', 'base', 'modifi', 'extend', 'metric', 'baselin', 'accord', 'perform', 'recal', 'standard', 'figur', 'comparison', 'yield', 'outperform', 'increas', 'stateoftheart', 'accuraci', 'method', 'procedur', 'score', 'origin', 'highest', 'signific', 'higher', 'fscore', 'compar']

# %%
def get_cue_words(contexts) :
    dataset = {}
    for key in contexts.keys() :
        count_list = []
        for cit in contexts[key] :
            dict1 = {}
            dict1['paper_name'] = cit['paper_name']
            context_words = cit['context']
            cue_words = list(set(cue_word_list)&set(context_words))
            count = 0
            for word in cue_words :
                count+=context_words.count(word)
            dict1['cue_count'] = count
            count_list.append(dict1)
        dataset[key] = count_list
    return dataset

# %%
cue_count = get_cue_words(contexts)
pickle.dump(cue_count, open("pickles_data/cue_count.pkl", "wb"))

# %%
def get_context_count(citations):
    dataset = {}
    for key in citations :
        papers = citations[key]
        feat_list = []
        for paper in papers :
            dict1 = {}
            dict1['paper_name'] = paper['title']
            dict1['context_count'] = len(paper['cit'].findall("contexts/context"))
            feat_list.append(dict1)
        dataset[key] = feat_list
    return dataset

# %%
context_count = get_context_count(citations)
pickle.dump(context_count, open("pickles_data/context_count.pkl","wb"))

# %%
baselines = get_baselines()
tags = get_baseline_tags(baselines, citations)

# %%
pickle.dump(tags, open("pickles_data/baseline_tags.pkl","wb"))

# %%
year_diff = get_year_difference(citations)
# Out:
# 31943

# %%
pickle.dump(year_diff, open("pickles_data/year_diff.pkl", "wb"))

# %%
def get_dist_words(string, cit_auths=None):
    
    string = string.replace('-', '').lower()
    context_words = word_tokenize(string)
    final_context_words = []

    # conversion_dict = pickle.load(open('pickles/conversion_dict.pkl', 'rb'))

    orig_pos = []

    for i in range(len(context_words)):
        word = context_words[i]
        if word in stop_words:
            continue
        if re.fullmatch(year_regex, word): #or match_auths(word, cit_auths):
            continue
        if re.fullmatch(r'[0-9]+([.][0-9]+)?', word):
            word = '<number>'
            orig_pos.append(i)
            final_context_words.append(word)
        elif 'this_citation' in word:
            orig_pos.append(i)
            final_context_words.append('<this_citation>')
        elif re.fullmatch(r'[a-z]+', word):
            original_word = word
            word = lemmatizer.lemmatize(word)
            final_word = stemmer.stem(word)

            if final_word not in conversion_dict:
                conversion_dict[final_word] = {}

            if original_word not in conversion_dict[final_word]:
                conversion_dict[final_word][original_word] = 0
            conversion_dict[final_word][original_word]+=1

            orig_pos.append(i)
            final_context_words.append(final_word)

    # pickle.dump(conversion_dict, open('pickles/conversion_dict.pkl', 'wb'))

    word_dist = calc_dist(final_context_words, orig_pos)
    return final_context_words, word_dist

# %%
def calc_dist(context_words, orig_pos) :  
    distances = []
    pivot_positions = []
    max_pos = []
    for i in range(len(context_words)):
        if context_words[i]=='<this_citation>':	
            pivot_positions.append(orig_pos[i])
            max_pos.append(max(i, len(context_words)-i))

    for i in range(len(context_words)):
        if orig_pos[i] in pivot_positions:
            distances.append(0)
            continue
        else:
            dist = 1
            for k in range(len(pivot_positions)):
                pos = pivot_positions[k]
                dist = min(dist, (abs(pos-orig_pos[i])/max_pos[k])**2)
            distances.append(dist)

    return distances

# %%
def get_contexts_dist(citations) :
    dataset = {}
    count = 0
    for key in citations.keys():
        context_list = []
        for cit in citations[key] :
            dict1 = {}
            dict1['paper_name'] = cit['title']
            dict1['context'] = ""
            for context in cit['cit'].findall('contexts/context') :
                text = context.text.lower()
                citstr = context.get('citStr').lower()
                text = text.replace(citstr, "this_citation")
                dict1['context']+= text+" "
            dict1['context'], dict1['distances'] = get_dist_words(dict1['context'])
            context_list.append(dict1)
        dataset[key] = context_list
        count+=1
        if(count%100==0) :
            print(count)
    return dataset

# %%
contexts_dist = get_contexts_dist(citations)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300

# %%
pickle.dump(contexts_dist, open("pickles/contexts_dist.pkl","wb"))

# %%
def get_reduced_context(citations):
    dataset = {}
    count = 0
    for key in citations.keys():
        context_list = []
        for cit in citations[key] :
            dict1 = {}
            dict1['paper_name'] = cit['title']
            dict1['context'] = ""
            for context in cit['cit'].findall('contexts/context') :
                text = context.text.lower()
                citstr = context.get('citStr').lower()
                text = text.replace(citstr, "this_citation")
                a = len(text)
                text = text[a//2-500:a//2+500]
                dict1['context']+= text+" "
            dict1['context'] = get_words(dict1['context'])
            context_list.append(dict1)
        dataset[key] = context_list
        count+=1
        if(count%100==0) :
            print(count)
    return dataset

# %%
citations = get_citations("xmls/")

# %%
reduced_context = get_reduced_context(citations)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100

# %%
cue_words_reduced = get_cue_words(reduced_context)

# %%
pickle.dump(cue_words_reduced, open("pickles/cue_words_reduced.pkl", "wb"))

# %%
pickle.dump(reduced_context, open("pickles/reduced_context.pkl", "wb"))

# %%
tags = pickle.load(open("pickles_data/baseline_tags.pkl", "rb"))

# %%
def get_abstract_similarity() :
    abstracts = pickle.load(open("pickles_data/abstracts_total.pkl", "rb"))
    paper_info = pickle.load(open("pickles/paper_info.pickle","rb"))
    
    dataset = {}
    for key in paper_info :
        papers = paper_info[key]
        abstract = abstracts[key]
        data = []
        for paper in papers :
            abcit = paper['abstract']
            try :
                abcit = str(abcit)
            except :
                abcit = ""
            sim = find_common_words(abcit, abstract)
            dict1 = {}
            dict1['paper_name'] = paper['paper_name']
            dict1['abs_sim'] = sim
            data.append(dict1)
        dataset[key] = data
    return dataset

# %%
abs_sim = get_abstract_similarity()

# %%
pickle.dump(abs_sim, open("pickles_data/abstract_similarity.pkl", "wb"))
